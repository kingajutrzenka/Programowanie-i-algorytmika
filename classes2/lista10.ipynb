# %% [markdown]
# <a href="https://colab.research.google.com/github/kingajutrzenka/Programowanie-i-algorytmika/blob/main/classes2/lista10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lista 10**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def det(p, q, r): #bardzo ważno ważna
  xp, yp = p
  xq, yq = q
  xr, yr = r
  return xr*(yp - yq) - xq*(yp - yr) + xp*(yq - yr)

def sgn(a):
  if a>0:
    return 1
  if a<0:
    return -1
  return 0

p = (1,1)
q = (10, 1)
r = (6, 5)

print(det(p, q, r))
print(sgn(det(p, q, r)))
# Out:
# 36
# 1

# %% [markdown]
# ## **Zadanie 1.**
# Dany jest punkt i odcinek. Odpowiedz na pytanie, czy punkt należy do odcinka.

# %%
def det(p, q, r): #bardzo ważno ważna
  xp, yp = p
  xq, yq = q
  xr, yr = r
  return xr*(yp - yq) - xq*(yp - yr) + xp*(yq - yr)

def sgn(a):
  if a>0:
    return 1
  if a<0:
    return -1
  return 0

p = (1,1)
q = (10, 1)
r = (5, 1)

x=(sgn(det(p, q, r)))

xp, yp = p
xq, yq = q
xr, yr = r

if x==0:
  if xp <= xr <= xq and yp <= yr <= yq and x==0:
    print("punkt należy do odcinka")
  else:
    print("punkt nie należy do odcinka")

if det(p, q, r) >0 :
  print({"po lewej"})
elif det(p, q, r) == 0 :
  print("jest współliniowy")
else:
  print("po prawej")
print(det(p, q, r))
print(sgn(det(p, q, r)))
# Out:
# punkt należy do odcinka
# jest współliniowy
# 0
# 0

# %% [markdown]
# ## **Zadanie 3.**
#
# Dane są dwa odcinki. Odpowiedz na pytanie, czy odcinki przecinają się.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s = (0, 3)
r = (0, -4)
p = (-4, 0)
q = (4, 0)
b = (1, 0)
a = (0, 1)
c = (0, -2)

sgn(det(p, q, r)) != sgn(det(p, q, s)) and sgn(det(r, s, p)) != sgn(det(r, s, q))
# Out:
# True

# %% [markdown]
# ## **Zadanie 5.**
#
# Dany jest trójką i punkt. Zbadaj, czy punkt należy do trójkąta.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def odcinek(p, q, r):
  x = sgn(det(p, q, r))
  xp, yp = p
  xq, yq = q
  xr, yr = r
  return x==0 and xp <= xr <= xq and yp <= yr <= yq and x==0

# %%
print(odcinek(p, q, a))
# Out:
# False

# %%
def lewa(p, q, s, a):
  return sgn(det(p, q, a)) == sgn(det(q, s, a))

# %%
print(lewa(p, q, s, c))
# Out:
# False

# %%
def tr(p, q, s, a):
  """ if lewa(p, q, s, a):
    return True
  if odcinek(p, q, a):
    return True
  if odcinek(q, s, a):
    return True
  if odcinek(s, p, a):
    return True
  return False """
  return lewa(p, q, s, a) or odcinek(p, q, a) or odcinek(q, s, a) or odcinek(s, p, a)

# %%
print(tr(p, q, s, a))
# Out:
# True

# %% [markdown]
# ## **Zadanie 6**
#
# Dana jest liczba naturalna n oraz n-kąt wypukły i dodatkowy punkt. Zbadaj, czy punkt należy do
# wielokąta.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
lista_wierzchołków = [(-1, 4), (-4,0), (-3, -3), (2, -3), (4, 0), (4, 3) ]
      # v0      v1       v2        v3       v4      v5

# %%
"""V = (-1, 4) #punkt początkowy - v0
lista_trójkątów =[]
for i in range(1, len(lista_wierzchołków)):
  lista_trójkątów = """

# %% [markdown]
# KONIEC ON GITHUB I COŚ W DOMU :

# %% [markdown]
# ## **Zadanie 8.**
# Dana jest liczba naturalna n oraz n punktów na płaszczyźnie. Napisz program sortujący te punkty
# biegunowo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""def alfa(p):
  xp, yp = p
  dp = abs(xp) + abs(yp)
  if yp >= 0 and xp >= 0:
    return yp/dp
  if xp <= 0 and yp >= 0:
    return 2 - yp/dp
  if xp <= 0 and yp <= 0:
    return 2 + abs(yp)/dp
  if xp => 0 and yp <= 0:
    return 4 - abs(yp)/dp

print(alpha(q))"""
# Out:
# 'def alfa(p):\n  xp, yp = p\n  dp = abs(xp) + abs(yp)\n  if yp >= 0 and xp >= 0:\n    return yp/dp\n  if xp <= 0 and yp >= 0:\n    return 2 - yp/dp\n  if xp <= 0 and yp <= 0:\n    return 2 + abs(yp)/dp\n  if xp => 0 and yp <= 0:\n    return 4 - abs(yp)/dp\n  \nprint(alpha(q))'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# graham i jarvis
